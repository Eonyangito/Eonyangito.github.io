# %% [markdown]
# # Introduction
#
# On the last episode of Click Click Bang, having being Detective Kimani's last stint at the
# force for 40 years he is compelled to leave having not completed his most sort after case.
# He passes the case to the younger detectives but urges them to keep him in the loop and fortunate
# enough new findings emerge.
# Rumors fill the air as the notorious Kasisi and footballer turned thug Kevin are reported
# dead. Detective Kimani is finally almost cracking the biggest case of his career catching the
# infamous underground gang 'The Shadows' after he gets a tip that could lead him directly to them.
# Will he be able to take them down this round.......????????
#
# (Source: Click Click Bang. (2022). [Netflix]. Retrieved from http://www.netflix.com""")

# %%
# Click Click Bang Text Adventure Game


# Function to display win message
def win():
    print("\n🎉🌟 Congratulations! You successfully completed the mission in Click Click Bang. 🌟🎉")
    print("You've uncovered the mystery,emerged victorious and completed the case. 🕵️‍♂️🔍")

# Function to display fail message
def fail():
    print("\n😞🔥 You lost this round. Better luck next time. 🔥😞")

    
    
# Function for the first stage of the game
def stage_one():
    print("\n🌟 Welcome to Click Click Bang Adventure Game! 🌟")
    
    
    print("As rain pours down on the bustling streets of Nairobi, you, Detective Kimani, find yourself at the crossroads of a sinister conspiracy.")
    print("Recent incidents suggest the involvement of the notorious gang, 'The Shadows,' known for their elusive nature and  operations. 🔒📜")
    print("Determined to unravel the mystery, you step into the murky underworld, where danger and secrets reside . Your mission is clear: expose the truth, whatever it takes. ⚠️")

    
    # Player's choice in the first stage
    print("\nChoices:")
    
    
    print("a. Investigate immediately")
    print("b. Gather more information first")
    print("c. Call for backup")

    choice = input(prompt="Your choice: ").lower()

    # Check player's choice and provide outcomes
    if choice == 'a' or choice == 'investigate':
        print("\n🕵️‍♂️ You decide to dive straight into the investigation, following a cryptic message to an abandoned warehouse.")
        print("Inside, the air is thick with tension. You uncover a hidden room with coded messages on the walls.")
        print("The code appears complex, and you need to decipher it to proceed. 🔐")
        return True
    elif choice == 'b' or choice == 'gather':
        print("\n📚 Opting for a cautious approach, you head to the local police station to gather intel.")
        print("There, you learn about recent criminal activities and a potential link to 'The Shadows.'")
        print("Equipped with information, you proceed with a lead pointing to a mysterious alley.")
        return False
    elif choice == 'c' or choice == 'call':
        print("\n🚓 Realizing the dangers that lie ahead, you decide to call for backup.")
        print("Your fellow detectives join you, and together, you follow a tip leading to a suspicious location.")
        print("The journey unfolds as you prepare to face the unknown. 👥🌧️")
        return True
    else:
        print("\n❌ Invalid choice. The investigation continues cautiously. ❌")
        return False

   
    
    
# Function for the second stage of the game
def stage_two():
    print("\n📜 Deciphering the code reveals a connection to an underground gang known as 'The Shadows.' 🌌")
    print("To gather more evidence, you decide to infiltrate their secret meeting.")
    print("As you sneak into their hideout, you notice two doors: one on the left and one on the right.")

    # Player's choice in the second stage
    print("\nChoices:")
    print("a. Enter the left door")
    print("b. Enter the right door")
    print("c. Find an alternate route")

    choice = input(prompt="Your choice: ").lower()

    # Check player's choice and provide outcomes
    if choice == 'a' or choice == 'left':
        print("\n📖 You cautiously enter the left door, discovering a dimly lit room with a large table covered in maps and documents.")
        print("You find valuable information about 'The Shadows' plans, but suddenly, an alarm is triggered!")
        print("You must escape quickly to avoid detection. ⏳🚨")
        return True
    elif choice == 'b' or choice == 'right':
        print("\n🚪 You choose not to enter the left door, deciding to explore the right side of the hideout.")
        print("While there, you overhear hushed conversations that hint at the gang's next move.")
        print("Now armed with insider knowledge, you plan your next move.")
        return False
    elif choice == 'c' or choice == 'alternate':
        print("\n🗺️ You decide to find an alternate route, avoiding the doors to stay undetected.")
        print("Exploring the periphery of the hideout, you discover a ventilation duct.")
        print("Cautiously crawling through, you manage to gather valuable intel without triggering any alarms. 🕵️‍♂️👍")
        return True
    else:
        print("\n❌ Invalid choice. Proceed with caution. ❌")
        return False

    
    
    
# Function for the third stage of the game
def stage_three():
    print("\n🔫 Armed with crucial evidence, you receive intel about the gang's leader's location.")
    print("You arrive at an abandoned warehouse where the leader is rumored to be.")

    # Player's choice in the third stage
    print("\nChoices:")
    print("a. Confront the leader directly")
    print("b. Observe from a distance first")
    print("c. Call for backup")

    choice = input(prompt="Your choice: ").lower()

    # Check player's choice and provide outcomes
    if choice == 'a' or choice == 'confront':
        print("\n💥 You gather your team and boldly confront the gang leader inside the warehouse.")
        print("The leader, surprised by your bravery, engages in a tense standoff.")
        print("With your evidence and courage, you bring the leader to justice. ✊🏽🔍")
        return True
    elif choice == 'b' or choice == 'observe':
        print("\n🔍 You decide not to confront the leader directly, choosing to observe from a safe distance.")
        print("While observing, you notice the gang's illegal activities and gather evidence.")
        print("Now, armed with irrefutable proof, you plan your next move.")
        return False
    elif choice == 'c' or choice == 'call':
        print("\n🚨 You call for backup before confronting the leader.")
        print("The backup arrives swiftly, ensuring a safer confrontation. 👥🚓")
        print("Together, you corner the gang leader and prepare for a decisive showdown.")
        print("The warehouse echoes with tension as you face the final challenge. ⚔️🌃")
        return True
    else:
        print("\n❌ Invalid choice. Proceed with care. ❌")
        return False

    
    
# Main Game Loop
while True:
    # Check each stage sequentially
    if stage_one():
        if stage_two():
            if stage_three():
                win()
                break
            else:
                fail()
                print("Returning to the start of Stage Three. ↩️")
        else:
            fail()
            print("Returning to the start of Stage Two. ↩️")
    else:
        fail()
        print("Returning to the start of Stage One. ↩️")
# Out:
# 🌟 Welcome to Click Click Bang Adventure Game! 🌟
# As rain pours down on the bustling streets of Nairobi, you, Detective Kimani, find yourself at the crossroads of a sinister conspiracy.
# Recent incidents suggest the involvement of the notorious gang, 'The Shadows,' known for their elusive nature and  operations. 🔒📜
# Determined to unravel the mystery, you step into the murky underworld, where danger and secrets reside . Your mission is clear: expose the truth, whatever it takes. ⚠️
#
# Choices:
# a. Investigate immediately
# b. Gather more information first
# c. Call for backup
# Your choice: a
#
# 🕵️‍♂️ You decide to dive straight into the investigation, following a cryptic message to an abandoned warehouse.
# Inside, the air is thick with tension. You uncover a hidden room with coded messages on the walls.
# The code appears complex, and you need to decipher it to proceed. 🔐
#
# 📜 Deciphering the code reveals a connection to an underground gang known as 'The Shadows.' 🌌
# ...
